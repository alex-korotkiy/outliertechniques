# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, HTML
import os


folder = 'Metrics'
datasets = ['ALOI', 'ForestCover', 'Satellite', 'Shuttle', 'Synthetic']
dimensions = [27, 10, 36, 9, 100]
alg_names = ['Base', 'TI', 'COR', 'TICOR', 'TICORDP']
prefixes = ['ALOI', 'covtype', 'sat', 'Shuttle', 'Synthetic']
formats = ['gray', 'r-.', 'g:', 'y--', 'm+']

def getDistanceName(fileName):
    parts = fileName.split('.')
    subParts = parts[0].split('_')
    return subParts[-1]

def round_to_significant_digits(value, n):
    if value == 0:
        return f"{0:.{n-1}f}"  # Special case for 0

    magnitude = -int(f"{value:.1e}".split('e')[1])
    round_factor = n - 1 + magnitude
    rounded_value = round(value, round_factor)
    if(round_factor < 0):
        return str(int(rounded_value))

    format_string = f"{{:.{n - 1 + magnitude}f}}"
    return format_string.format(rounded_value)

def format_base_dc(dc):
    return f"{round_to_significant_digits(dc, 5)}"

def format_dc_and_percent(dc, percent):
    return f"{round_to_significant_digits(dc, 5)} ({round_to_significant_digits(percent, 4)}%)"


def displayDataSetTable(fileName):
    df = pd.read_csv(folder + '/' + fileName)

    cols = ['Samples', 'Base distance calculations, mln']
    rename_cols = {}
 
    df[cols[1]] = df.apply(lambda r: format_base_dc(r['Base_DistanceCalculations_Count_Avg']/1000000.0), axis=1)
    
    for i in range(1, len(alg_names)):
        alg_name = alg_names[i]
        col_name = alg_name + '_DistanceCalculations_Count_Avg'

        if col_name in df.columns:
            df[alg_name] = df.apply(lambda r: format_dc_and_percent(r[col_name]/1000000.0, (r[col_name]/r['Base_DistanceCalculations_Count_Avg'])*100.0), axis=1)
            cols.append(alg_name)
            rename_cols[alg_name] = f"{alg_name} distance calculations, mln (% to base)"
        
    
    df_display = df[cols].copy().rename(columns=rename_cols)
    display(HTML(df_display.to_html(index=False)))


def displayDataSetCharts(datasetName, dimension, fileName):

    distanceName = getDistanceName(fileName)
    df = pd.read_csv(folder + '/' + fileName)

    plt.figure(figsize=(15, 5))
    plt.title(f'Dataset: {datasetName}. Dimension: {str(dimension)}. Distance: {distanceName}. # of distance calculations')
    plt.xlabel('# of samples')
    plt.ylabel('# of distance calculations')
    plt.grid(True)


    for i in range(len(alg_names)):
        alg_name = alg_names[i]
        fmt = formats[i]
        column_name = alg_name + '_' + 'DistanceCalculations_Count_Avg'
        if column_name in df.columns:
            plt.plot(df['Samples'], df[column_name], fmt, label=alg_name)

    plt.xlim(left = 0)
    plt.ylim(bottom = 0)
    plt.legend()
    plt.show()


    plt.figure(figsize=(15, 5))
    plt.title(f'Dataset: {datasetName}. Dimension: {str(dimension)}. Distance: {distanceName}. # of distance calculations to base, %')
    plt.xlabel('# of samples')
    plt.ylabel('# of distance calculations to base, %')
    plt.grid(True)

    for i in range(1, len(alg_names)):
        alg_name = alg_names[i]
        fmt = formats[i]
        column_name = alg_name + '_' + 'DistanceCalculations_Count_Avg'
        if column_name in df.columns:
            plt.plot(df['Samples'], (df[column_name]/df['Base_DistanceCalculations_Count_Avg'])*100, fmt, label=alg_name)

    plt.xlim(left = 0)
    plt.ylim(bottom = 0)
    plt.legend()
    plt.show()


reportFiles = list(filter(lambda f: f.endswith('.csv'), os.listdir(folder)))

for i in range(len(datasets)):
    
    dataset_name = datasets[i]
    prefix = prefixes[i]
    dimension = dimensions[i]
    dataset_files = list(filter(lambda f: f.startswith(prefix + '_'), reportFiles))
    
    if len(dataset_files) == 0:
        continue
    
    display(HTML(f"<h2>Dataset: {dataset_name}</h2>"))
    
    for f in dataset_files:

        distance_name = getDistanceName(f)        
        display(HTML(f"<h3>Distance: {distance_name}</h3>"))
        displayDataSetTable(f)
        displayDataSetCharts(dataset_name, dimension, f)
# Out:
# <h2>Dataset: ALOI</h2>
# <h3>Distance: Chebyshev</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Samples</th>
#       <th>Base distance calculations, mln</th>
#       <th>TI distance calculations, mln (% to base)</th>
#       <th>COR distance calculations, mln (% to base)</th>
#       <th>TICOR distance calculations, mln (% to base)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.49994</td>
#       <td>0.32329 (64.67%)</td>
#       <td>0.11752 (23.51%)</td>
#       <td>0.11151 (22.30%)</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.74988</td>
#       <td>0.45031 (60.05%)</td>
#       <td>0.15760 (21.02%)</td>
#       <td>0.14566 (19.42%)</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.9998</td>
#       <td>0.58531 (58.54%)</td>
#       <td>0.20133 (20.14%)</td>
#       <td>0.18320 (18.32%)</td>
#     </tr>
#     <tr>
#       <td>30</td>
# ...
